# %% [markdown]
# # Neural Network gas_turbine

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import GridSearchCV, KFold

# %%
gas_turbines = pd.read_csv('gas_turbines.csv')
gas_turbines
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# 0      3.1547  82.722
# 1      3.2363  82.776
# 2      3.2012  82.468
# 3      3.1923  82.670
# 4      3.2484  82.311
# ...       ...     ...
# 15034  4.5186  79.559
# 15035  4.8470  79.917
# 15036  7.9632  90.912
# 15037  6.2494  93.227
# 15038  4.9816  92.498
#
# [15039 rows x 11 columns]

# %%
gas_turbines.isnull().sum().sum()
# Out:
# 0

# %%
gas_turbines.describe()
# Out:
#                  AT           AP            AH          AFDP          GTEP  \
# count  15039.000000  15039.00000  15039.000000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174      4.200294     25.419061
# std        7.574323      6.41076     13.793439      0.760197      4.173916
# min        0.522300    985.85000     30.344000      2.087400     17.878000
# 25%       11.408000   1008.90000     69.750000      3.723900     23.294000
# 50%       18.186000   1012.80000     82.266000      4.186200     25.082000
# 75%       23.862500   1016.90000     90.043500      4.550900     27.184000
# max       34.929000   1034.20000    100.200000      7.610600     37.402000
#
#                 TIT           TAT           TEY           CDP            CO  \
# count  15039.000000  15039.000000  15039.000000  15039.000000  15039.000000
# mean    1083.798770    545.396183    134.188464     12.102353      1.972499
# std       16.527806      7.866803     15.829717      1.103196      2.222206
# min     1000.800000    512.450000    100.170000      9.904400      0.000388
# 25%     1079.600000    542.170000    127.985000     11.622000      0.858055
# 50%     1088.700000    549.890000    133.780000     12.025000      1.390200
# 75%     1096.000000    550.060000    140.895000     12.578000      2.160400
# max     1100.800000    550.610000    174.610000     15.081000     44.103000
#
#                 NOX
# count  15039.000000
# mean      68.190934
# std       10.470586
# min       27.765000
# 25%       61.303500
# 50%       66.601000
# 75%       73.935500
# max      119.890000

# %%
corr = gas_turbines[gas_turbines.columns[0:11]].corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Neural Network Model

# %%
X = data_raw.drop(columns = ['TEY'], axis = 1) 
y = data_raw.iloc[:,7]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 42)
X_train_scaled = scale(X_train)
X_test_scaled = scale(X_test)
X_test_scaled
# Out:
# array([[ 0.82623246, -0.43954308, -0.25924569, ...,  0.10039242,
#         -0.3796304 , -0.69217007],
#        [ 0.35282087,  0.23279782,  0.80230139, ..., -1.18541222,
#          0.39149515, -1.09475442],
#        [ 0.32839008, -0.07135639,  0.25312287, ...,  0.01665304,
#         -0.00296896, -0.31891741],
#        ...,
#        [-0.74071701,  0.37687087,  0.43427425, ...,  1.77157829,
#         -1.00127821, -0.4818816 ],
#        [-0.49965786, -0.39151873,  0.64680105, ..., -0.26517949,
#         -0.48137538,  0.12808615],
#        [ 0.13151427,  0.32884652,  0.98830762, ..., -1.40331469,
#          0.13152215, -0.64456466]])

# %%
input_size = len(X.columns)
output_size = 1
hidden_layer_size = 50

model = tf.keras.Sequential([
                                
                               tf.keras.layers.Dense(hidden_layer_size, input_dim = input_size, activation = 'relu'),
                               tf.keras.layers.Dense(hidden_layer_size, activation = 'relu'),
                               tf.keras.layers.Dense(hidden_layer_size, activation = 'relu'),
                               tf.keras.layers.Dense(hidden_layer_size, activation = 'relu'),     
                               tf.keras.layers.Dense(output_size)
    
    
                                ])

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate = 0.03)
model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['MeanSquaredError'])

# %%
num_epochs = 50
early_stopping = tf.keras.callbacks.EarlyStopping(patience = 2)
model.fit(X_train_scaled, y_train, callbacks = early_stopping, validation_split = 0.1, epochs = num_epochs, verbose = 2)
# Out:
# Epoch 1/50
# 381/381 - 1s - loss: 6525.1699 - mean_squared_error: 6525.1699 - val_loss: 456.7303 - val_mean_squared_error: 456.7303 - 612ms/epoch - 2ms/step
# Epoch 2/50
# 381/381 - 0s - loss: 270.1799 - mean_squared_error: 270.1799 - val_loss: 202.5591 - val_mean_squared_error: 202.5591 - 309ms/epoch - 810us/step
# Epoch 3/50
# 381/381 - 0s - loss: 138.4308 - mean_squared_error: 138.4308 - val_loss: 129.4862 - val_mean_squared_error: 129.4862 - 362ms/epoch - 950us/step
# Epoch 4/50
# 381/381 - 0s - loss: 88.6042 - mean_squared_error: 88.6042 - val_loss: 90.4479 - val_mean_squared_error: 90.4479 - 396ms/epoch - 1ms/step
# Epoch 5/50
# 381/381 - 0s - loss: 59.9985 - mean_squared_error: 59.9985 - val_loss: 61.6647 - val_mean_squared_error: 61.6647 - 322ms/epoch - 844us/step
# Epoch 6/50
# 381/381 - 0s - loss: 40.3992 - mean_squared_error: 40.3992 - val_loss: 40.6189 - val_mean_squared_error: 40.6189 - 336ms/epoch - 881us/step
# Epoch 7/50
# 381/381 - 0s - loss: 27.4605 - mean_squared_error: 27.4605 - val_loss: 28.4735 - val_mean_squared_error: 28.4735 - 333ms/epoch - 873us/step
# Epoch 8/50
# 381/381 - 0s - loss: 18.1192 - mean_squared_error: 18.1192 - val_loss: 17.9648 - val_mean_squared_error: 17.9648 - 333ms/epoch - 875us/step
# Epoch 9/50
# 381/381 - 0s - loss: 11.9098 - mean_squared_error: 11.9098 - val_loss: 11.3630 - val_mean_squared_error: 11.3630 - 338ms/epoch - 886us/step
# Epoch 10/50
# 381/381 - 0s - loss: 7.9701 - mean_squared_error: 7.9701 - val_loss: 7.4148 - val_mean_squared_error: 7.4148 - 332ms/epoch - 873us/step
# Epoch 11/50
# 381/381 - 0s - loss: 5.3383 - mean_squared_error: 5.3383 - val_loss: 5.1352 - val_mean_squared_error: 5.1352 - 330ms/epoch - 865us/step
# Epoch 12/50
# 381/381 - 0s - loss: 3.6200 - mean_squared_error: 3.6200 - val_loss: 3.2509 - val_mean_squared_error: 3.2509 - 352ms/epoch - 925us/step
# Epoch 13/50
# 381/381 - 0s - loss: 2.5721 - mean_squared_error: 2.5721 - val_loss: 2.8700 - val_mean_squared_error: 2.8700 - 294ms/epoch - 770us/step
# Epoch 14/50
# 381/381 - 0s - loss: 1.8668 - mean_squared_error: 1.8668 - val_loss: 1.9390 - val_mean_squared_error: 1.9390 - 302ms/epoch - 791us/step
# Epoch 15/50
# 381/381 - 0s - loss: 1.4526 - mean_squared_error: 1.4526 - val_loss: 1.3327 - val_mean_squared_error: 1.3327 - 368ms/epoch - 966us/step
# Epoch 16/50
# 381/381 - 0s - loss: 1.0937 - mean_squared_error: 1.0937 - val_loss: 1.0916 - val_mean_squared_error: 1.0916 - 360ms/epoch - 944us/step
# Epoch 17/50
# 381/381 - 0s - loss: 0.8995 - mean_squared_error: 0.8995 - val_loss: 0.8502 - val_mean_squared_error: 0.8502 - 328ms/epoch - 860us/step
# Epoch 18/50
# 381/381 - 0s - loss: 0.7732 - mean_squared_error: 0.7732 - val_loss: 0.7047 - val_mean_squared_error: 0.7047 - 412ms/epoch - 1ms/step
# Epoch 19/50
# 381/381 - 0s - loss: 0.6935 - mean_squared_error: 0.6935 - val_loss: 0.6647 - val_mean_squared_error: 0.6647 - 343ms/epoch - 899us/step
# Epoch 20/50
# 381/381 - 0s - loss: 0.6363 - mean_squared_error: 0.6363 - val_loss: 0.5553 - val_mean_squared_error: 0.5553 - 352ms/epoch - 925us/step
# Epoch 21/50
# 381/381 - 0s - loss: 0.6091 - mean_squared_error: 0.6091 - val_loss: 0.7468 - val_mean_squared_error: 0.7468 - 325ms/epoch - 853us/step
# Epoch 22/50
# 381/381 - 0s - loss: 0.5581 - mean_squared_error: 0.5581 - val_loss: 0.5024 - val_mean_squared_error: 0.5024 - 332ms/epoch - 870us/step
# Epoch 23/50
# 381/381 - 0s - loss: 0.5433 - mean_squared_error: 0.5433 - val_loss: 0.4871 - val_mean_squared_error: 0.4871 - 380ms/epoch - 996us/step
# Epoch 24/50
# 381/381 - 0s - loss: 0.5306 - mean_squared_error: 0.5306 - val_loss: 0.5887 - val_mean_squared_error: 0.5887 - 352ms/epoch - 925us/step
# Epoch 25/50
# 381/381 - 0s - loss: 0.5500 - mean_squared_error: 0.5500 - val_loss: 0.5467 - val_mean_squared_error: 0.5467 - 358ms/epoch - 940us/step

# %%
test_loss, mean_squared_error = model.evaluate(X_test_scaled, y_test)
# Out:
# 47/47 [==============================] - 0s 1ms/step - loss: 3.2091 - mean_squared_error: 3.2091

# %%
predictions = model.predict_on_batch(X_test_scaled)

# %%
plt.scatter(y_test, predictions)

# %%
predictions_df = pd.DataFrame()
predictions_df['Actual'] = y_test
predictions_df['Predicted'] = predictions
predictions_df['% Error'] = abs(predictions_df['Actual'] - predictions_df['Predicted'])/predictions_df['Actual']*100
predictions_df.reset_index(drop = True)
# Out:
#       Actual   Predicted   % Error
# 0     134.46  133.913391  0.406522
# 1     111.88  111.786995  0.083129
# 2     133.72  134.165680  0.333293
# 3     133.79  132.765610  0.765670
# 4     110.77  109.831299  0.847433
# ...      ...         ...       ...
# 1499  132.85  133.057220  0.155981
# 1500  125.07  123.627838  1.153084
# 1501  160.95  157.664520  2.041305
# 1502  133.12  131.508514  1.210551
# 1503  111.79  111.406967  0.342636
#
# [1504 rows x 3 columns]

# %%
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 50)                550
#
#  dense_6 (Dense)             (None, 50)                2550
#
#  dense_7 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 3,151
# Trainable params: 3,151
# Non-trainable params: 0
# _________________________________________________________________
# None
